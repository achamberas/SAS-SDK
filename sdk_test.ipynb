# %%
pip install git+https://Steritas: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@github.com/Steritas/steritas_gti.git@staging
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#   Cloning https://Steritas:****@github.com/Steritas/steritas_gti.git (to revision staging) to /private/var/folders/xr/smm2095x7txfhj4s2x6wzqyw0000gn/T/pip-req-build-rwmclvwr
#   Running command git clone --filter=blob:none --quiet 'https://Steritas:****@github.com/Steritas/steritas_gti.git' /private/var/folders/xr/smm2095x7txfhj4s2x6wzqyw0000gn/T/pip-req-build-rwmclvwr
#   Running command git checkout -b staging --track origin/staging
#   Switched to a new branch 'staging'
#   branch 'staging' set up to track 'origin/staging'.
#   Resolved https://Steritas:****@github.com/Steritas/steritas_gti.git to commit 5b5f7f007aa05f0e1eaa7695c47463c5e87ebdfa
#   Installing build dependencies ... done
# ...

# %%
import pandas as pd
from steritas_gti import calculate_score

input_subjects = pd.read_excel('Sample_Data_BMI_Check.xlsx', sheet_name='input_data')
input_subjects['visit_date'] = input_subjects['visit_date'].astype(str)
#input_subjects['height'] = None
#input_subjects['weight'] = None
#input_subjects['height'] = 5.5
#input_subjects['weight'] = (input_subjects['bmi']/703) * (input_subjects['height']*12).pow(2)


results = calculate_score(
    input_subjects, 
    baseline="previous", 
    algorithm = 'mdgti', 
    include=[], 
    output_format = 'df', 
    unit = 1,
    fill_missing=False
)

print(input_subjects)
results['score']
# Out:
#   subject_id  visit_number  visit_date  systolic  diastolic  hba1c  \
# 0  Patient A             1  2016-02-16       122         68    6.1
# 1  Patient A             2  2016-06-23       142         68    6.9
# 2  Patient B             1  2015-07-23       122         70    5.8
# 3  Patient B             2  2016-09-30       138         76    6.1
# 4  Patient C             1  2016-05-22       136         48    8.0
# 5  Patient C             2  2016-10-03       116         50    9.7
#
#    lipid_intent  bp_intent  glucose_intent  ldl  ldl_target  height  \
# 0             0          0               0  145        1.81     5.5
# 1             0          0               1   97        1.81     5.5
# 2             0          0               0  105        1.81     5.5
# 3             1          0               0   93        1.81     5.5
# 4             0          1               1   64        1.81     5.5
# 5             1          0               1   50        1.81     5.5
#
# ...
